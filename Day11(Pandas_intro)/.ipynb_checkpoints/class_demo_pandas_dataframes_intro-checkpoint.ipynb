# %% [markdown]
# # Pandas DataFrames Basics

# %%
import pandas as pd

# %%
nba = pd.read_csv("data/nba.csv")

# %%
# look at the first 10 rows of data
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0
# 7            Gonzaga   2165160.0
# 8         Louisville   1824360.0
# 9     Oklahoma State   3431040.0

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# ## Attributes

# %%
# get an idea of what your data looks like
nba.shape
# Out:
# (458, 9)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.Position.head()
# Out:
# 0    PG
# 1    SF
# 2    SG
# 3    SG
# 4    PF
# Name: Position, dtype: object

# %%
nba['Position'].head()
# Out:
# 0    PG
# 1    SF
# 2    SG
# 3    SG
# 4    PF
# Name: Position, dtype: object

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %% [markdown]
# ## Methods

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
nba.Salary.sum()
# Out:
# 2159837111.0

# %%
nba.Salary.count()
# Out:
# 446

# %%
nba.Salary.sum()
# Out:
# 2159837111.0

# %%
nba['Sport'] = "basketball"
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# ..                       ...                     ...     ...      ...   ...
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
# 435           Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0
# 436           Damian Lillard  Portland Trail Blazers     0.0       PG  25.0
# 437            C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0
# 438             Luis Montero  Portland Trail Blazers    44.0       SG  23.0
# 439            Mason Plumlee  Portland Trail Blazers    24.0        C  26.0
# 440            Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 441              Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 442            Trevor Booker               Utah Jazz    33.0       PF  28.0
# 443               Trey Burke               Utah Jazz     3.0       PG  23.0
# 444               Alec Burks               Utah Jazz    10.0       SG  24.0
# 445               Dante Exum               Utah Jazz    11.0       PG  20.0
# 446           Derrick Favors               Utah Jazz    15.0       PF  24.0
# 447              Rudy Gobert               Utah Jazz    27.0        C  23.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 450               Joe Ingles               Utah Jazz     2.0       SF  28.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 454                Raul Neto               Utah Jazz    25.0       PG  24.0
# 455             Tibor Pleiss               Utah Jazz    21.0        C  26.0
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
# 457                      NaN                     NaN     NaN      NaN   NaN
#
#     Height  Weight            College      Salary       Sport
# 0      6-2   180.0              Texas   7730337.0  basketball
# 1      6-6   235.0          Marquette   6796117.0  basketball
# 2      6-5   205.0  Boston University         NaN  basketball
# 3      6-5   185.0      Georgia State   1148640.0  basketball
# 4     6-10   231.0                NaN   5000000.0  basketball
# 5      6-9   240.0                NaN  12000000.0  basketball
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport League
# 0              Texas  7730337.0  basketball    NBA
# 1          Marquette  6796117.0  basketball    NBA
# 2  Boston University        NaN  basketball    NBA
# 3      Georgia State  1148640.0  basketball    NBA
# 4                NaN  5000000.0  basketball    NBA

# %%
# insert into middle of the dataframe
nba.insert(8,"Race","",True)

# %%
nba[["Name","Team","Position"]].head()
# Out:
#             Name            Team Position
# 0  Avery Bradley  Boston Celtics       PG
# 1    Jae Crowder  Boston Celtics       SF
# 2   John Holland  Boston Celtics       SG
# 3    R.J. Hunter  Boston Celtics       SG
# 4  Jonas Jerebko  Boston Celtics       PF

# %%
nba[["Position","Team","Name"]].head()
# Out:
#   Position            Team           Name
# 0       PG  Boston Celtics  Avery Bradley
# 1       SF  Boston Celtics    Jae Crowder
# 2       SG  Boston Celtics   John Holland
# 3       SG  Boston Celtics    R.J. Hunter
# 4       PF  Boston Celtics  Jonas Jerebko

# %%
nba.sort_values("Weight", ascending=False).head(10)
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 405     Nikola Pekovic  Minnesota Timberwolves    14.0        C  30.0   6-11
# 302   Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 330       Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
# 395       Jusuf Nurkic          Denver Nuggets    23.0        C  21.0    7-0
# 188     Andre Drummond         Detroit Pistons     0.0        C  22.0   6-11
# 41      Kevin Seraphin         New York Knicks     1.0        C  26.0   6-10
# 56       Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0   6-11
# 237      Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 176     Timofey Mozgov     Cleveland Cavaliers    20.0        C  29.0    7-1
# 155  Cristiano Felicio           Chicago Bulls     6.0       PF  23.0   6-10
#
#      Weight      College Race      Salary       Sport League
# 405   307.0          NaN       12100000.0  basketball    NBA
# 302   290.0          NaN        1200000.0  basketball    NBA
# 330   289.0          NaN       13500000.0  basketball    NBA
# 395   280.0          NaN        1842000.0  basketball    NBA
# 188   279.0  Connecticut        3272091.0  basketball    NBA
# 41    278.0          NaN        2814000.0  basketball    NBA
# 56    275.0         Duke        4582680.0  basketball    NBA
# 237   275.0          NaN        5200000.0  basketball    NBA
# 176   275.0          NaN        4950000.0  basketball    NBA
# 155   275.0          NaN         525093.0  basketball    NBA

# %%
#sort by multiple columns
nba.sort_values(["Weight","Age","Number"], ascending=False).head(10)
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 405     Nikola Pekovic  Minnesota Timberwolves    14.0        C  30.0   6-11
# 302   Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 330       Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
# 395       Jusuf Nurkic          Denver Nuggets    23.0        C  21.0    7-0
# 188     Andre Drummond         Detroit Pistons     0.0        C  22.0   6-11
# 41      Kevin Seraphin         New York Knicks     1.0        C  26.0   6-10
# 237      Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 176     Timofey Mozgov     Cleveland Cavaliers    20.0        C  29.0    7-1
# 23         Brook Lopez           Brooklyn Nets    11.0        C  28.0    7-0
# 155  Cristiano Felicio           Chicago Bulls     6.0       PF  23.0   6-10
#
#      Weight      College Race      Salary       Sport League
# 405   307.0          NaN       12100000.0  basketball    NBA
# 302   290.0          NaN        1200000.0  basketball    NBA
# 330   289.0          NaN       13500000.0  basketball    NBA
# 395   280.0          NaN        1842000.0  basketball    NBA
# 188   279.0  Connecticut        3272091.0  basketball    NBA
# 41    278.0          NaN        2814000.0  basketball    NBA
# 237   275.0          NaN        5200000.0  basketball    NBA
# 176   275.0          NaN        4950000.0  basketball    NBA
# 23    275.0     Stanford       19689000.0  basketball    NBA
# 155   275.0          NaN         525093.0  basketball    NBA

# %%
new_nba = nba[["Name","Team","Number","Position","Age","Weight","Salary"]]
new_nba.head()
# Out:
#             Name            Team  Number Position   Age  Weight     Salary
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0  7730337.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0  6796117.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0   205.0        NaN
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0  1148640.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0  5000000.0

# %%
# drop an entire column
nba = nba.drop("Race", axis = 1)

# %%
nba.insert(5, "Fake", "empty", True)
nba.head()
# Out:
#             Name            Team  Number Position   Age   Fake Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  empty    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  empty    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0  empty    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0  empty    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0  empty   6-10   231.0
#
#              College     Salary       Sport League
# 0              Texas  7730337.0  basketball    NBA
# 1          Marquette  6796117.0  basketball    NBA
# 2  Boston University        NaN  basketball    NBA
# 3      Georgia State  1148640.0  basketball    NBA
# 4                NaN  5000000.0  basketball    NBA

# %%
nba.drop("Fake",axis=1, inplace=True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport League
# 0              Texas  7730337.0  basketball    NBA
# 1          Marquette  6796117.0  basketball    NBA
# 2  Boston University        NaN  basketball    NBA
# 3      Georgia State  1148640.0  basketball    NBA
# 4                NaN  5000000.0  basketball    NBA

# %%
nba.insert(5,"Age in Dog Years",nba.Age.mul(7), True)

# %%
nba.drop("Dog Years", inplace=True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-c4e5f9fefa27> in <module>
# ----> 1 nba.drop("Dog Years", inplace=True, axis = 1)
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['Dog Years'] not found in axis"

# %%
nba.head(5)
# Out:
#             Name            Team  Number Position   Age  Age in Dog Years  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0             175.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0             175.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0             189.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0             154.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0             203.0
#
#   Height  Weight            College     Salary       Sport League
# 0    6-2   180.0              Texas  7730337.0  basketball    NBA
# 1    6-6   235.0          Marquette  6796117.0  basketball    NBA
# 2    6-5   205.0  Boston University        NaN  basketball    NBA
# 3    6-5   185.0      Georgia State  1148640.0  basketball    NBA
# 4   6-10   231.0                NaN  5000000.0  basketball    NBA

# %%
nba.Position.value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba.Position = nba.Position.astype('category')
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 12 columns):
# Name                457 non-null object
# Team                457 non-null object
# Number              457 non-null float64
# Position            457 non-null category
# Age                 457 non-null float64
# Age in Dog Years    457 non-null float64
# Height              457 non-null object
# Weight              457 non-null float64
# College             373 non-null object
# Salary              446 non-null float64
# Sport               458 non-null object
# League              458 non-null object
# dtypes: category(1), float64(5), object(6)
# memory usage: 40.1+ KB

# %%
nba['Team'] = nba.Team.astype("category")
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 12 columns):
# Name                457 non-null object
# Team                457 non-null category
# Number              457 non-null float64
# Position            457 non-null category
# Age                 457 non-null float64
# Age in Dog Years    457 non-null float64
# Height              457 non-null object
# Weight              457 non-null float64
# College             373 non-null object
# Salary              446 non-null float64
# Sport               458 non-null object
# League              458 non-null object
# dtypes: category(2), float64(5), object(5)
# memory usage: 38.4+ KB

# %%
nba['Number'] = nba.Number.astype("int")
nba.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-b799066b64be> in <module>
# ----> 1 nba['Number'] = nba.Number.astype("int")
#       2 nba.info()
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~/Sites/studio/760/Lesson_Resources/python/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     674
#     675         if not np.isfinite(arr).all():
# --> 676             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     677                              'integer')
#     678
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 12 columns):
# Name                457 non-null object
# Team                457 non-null category
# Number              457 non-null float64
# Position            457 non-null category
# Age                 457 non-null float64
# Age in Dog Years    457 non-null float64
# Height              457 non-null object
# Weight              457 non-null float64
# College             373 non-null object
# Salary              446 non-null float64
# Sport               458 non-null object
# League              458 non-null object
# dtypes: category(2), float64(5), object(5)
# memory usage: 38.4+ KB

# %%
nba.dropna(inplace=True)

# %%
nba.tail()
# Out:
#               Name       Team  Number Position   Age  Age in Dog Years Height  \
# 449    Rodney Hood  Utah Jazz     5.0       SG  23.0             161.0    6-8
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0             182.0    6-6
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0             140.0   6-10
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0             182.0    6-3
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0             182.0    7-0
#
#      Weight   College     Salary       Sport League
# 449   206.0      Duke  1348440.0  basketball    NBA
# 451   206.0    Dayton   981348.0  basketball    NBA
# 452   234.0  Kentucky  2239800.0  basketball    NBA
# 453   203.0    Butler  2433333.0  basketball    NBA
# 456   231.0    Kansas   947276.0  basketball    NBA

# %%
Jazz_mask = nba.Team == "Utah Jazz"
nba[Jazz_mask]
# Out:
#                Name       Team  Number Position   Age  Age in Dog Years  \
# 442   Trevor Booker  Utah Jazz    33.0       PF  28.0             196.0
# 443      Trey Burke  Utah Jazz     3.0       PG  23.0             161.0
# 444      Alec Burks  Utah Jazz    10.0       SG  24.0             168.0
# 446  Derrick Favors  Utah Jazz    15.0       PF  24.0             168.0
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0             182.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0             161.0
# 356             140.0    6-9   220.0     Arizona  4171680.0  basketball    NBA
# 377             140.0    6-7   205.0      Kansas  1920240.0  basketball    NBA
# 401             140.0    6-2   195.0        Duke  1282080.0  basketball    NBA
# 410             140.0    7-0   244.0    Kentucky  5703600.0  basketball    NBA
# 427             140.0    6-8   240.0      Kansas   525093.0  basketball    NBA
# 441             140.0    6-9   240.0     Indiana  2637720.0  basketball    NBA
# 452             140.0   6-10   234.0    Kentucky  2239800.0  basketball    NBA

# %%
high_paying = nba.Salary > 20000000
nba[high_paying]
# Out:
#                 Name                   Team  Number Position   Age  \
# 33   Carmelo Anthony        New York Knicks     7.0       SF  32.0
# 100       Chris Paul   Los Angeles Clippers     3.0       PG  31.0
# 164     Derrick Rose          Chicago Bulls     1.0       PG  27.0
# 339       Chris Bosh             Miami Heat     1.0       PF  32.0
# 414     Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0
#
#      Age in Dog Years Height  Weight       College      Salary       Sport  \
# 33              224.0    6-8   240.0      Syracuse  22875000.0  basketball
# 100             217.0    6-0   175.0   Wake Forest  21468695.0  basketball
# 164             189.0    6-3   190.0       Memphis  20093064.0  basketball
# 339             224.0   6-11   235.0  Georgia Tech  22192730.0  basketball
# 414             189.0    6-9   240.0         Texas  20158622.0  basketball
#
#     League
# 33     NBA
# 100    NBA
# 164    NBA
# 339    NBA
# 414    NBA

# %%
old_young = (nba.Age <20) | (nba.Age >38)
nba[old_young]
# Out:
#               Name               Team  Number Position   Age  \
# 122   Devin Booker       Phoenix Suns     1.0       SG  19.0
# 226  Rashad Vaughn    Milwaukee Bucks    20.0       SG  19.0
# 261   Vince Carter  Memphis Grizzlies    15.0       SG  39.0
# 298     Tim Duncan  San Antonio Spurs    21.0        C  40.0
# 304   Andre Miller  San Antonio Spurs    24.0       PG  40.0
#
#      Age in Dog Years Height  Weight         College     Salary       Sport  \
# 122             133.0    6-6   206.0        Kentucky  2127840.0  basketball
# 226             133.0    6-6   202.0            UNLV  1733040.0  basketball
# 261             273.0    6-6   220.0  North Carolina  4088019.0  basketball
# 298             280.0   6-11   250.0     Wake Forest  5250000.0  basketball
# 304             280.0    6-3   200.0            Utah   250750.0  basketball
#
#     League
# 122    NBA
# 226    NBA
# 261    NBA
# 298    NBA
# 304    NBA

# %%
nba.Age = nba.Age.astype("int")

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age  Age in Dog Years  \
# 0  Avery Bradley  Boston Celtics     0.0       PG   25             175.0
# 1    Jae Crowder  Boston Celtics    99.0       SF   25             175.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG   22             154.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF   21             147.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C   25             175.0
#
#   Height  Weight        College     Salary       Sport League
# 0    6-2   180.0          Texas  7730337.0  basketball    NBA
# 1    6-6   235.0      Marquette  6796117.0  basketball    NBA
# 3    6-5   185.0  Georgia State  1148640.0  basketball    NBA
# 6    6-8   235.0            LSU  1170960.0  basketball    NBA
# 7    7-0   238.0        Gonzaga  2165160.0  basketball    NBA

# %%
nba.Weight = nba.Weight.astype("int")

# %%
nba.Salary = nba.Salary.astype("int")

# %%
nba.Sport = nba.Sport.astype("category")
nba.League = nba.League.astype("category")
nba.College = nba.College.astype("category")
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 12 columns):
# Name                364 non-null object
# Team                364 non-null category
# Number              364 non-null float64
# Position            364 non-null category
# Age                 364 non-null int64
# Age in Dog Years    364 non-null float64
# Height              364 non-null object
# Weight              364 non-null int64
# College             364 non-null category
# Salary              364 non-null int64
# Sport               364 non-null category
# League              364 non-null category
# dtypes: category(5), float64(2), int64(3), object(2)
# memory usage: 32.3+ KB

# %%
nba.Number = nba.Number.astype("int")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 12 columns):
# Name                364 non-null object
# Team                364 non-null category
# Number              364 non-null int64
# Position            364 non-null category
# Age                 364 non-null int64
# Age in Dog Years    364 non-null float64
# Height              364 non-null object
# Weight              364 non-null int64
# College             364 non-null category
# Salary              364 non-null int64
# Sport               364 non-null category
# League              364 non-null category
# dtypes: category(5), float64(1), int64(4), object(2)
# memory usage: 32.3+ KB

# %%
nba.Height = nba.Height.astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 12 columns):
# Name                364 non-null object
# Team                364 non-null category
# Number              364 non-null int64
# Position            364 non-null category
# Age                 364 non-null int64
# Age in Dog Years    364 non-null float64
# Height              364 non-null category
# Weight              364 non-null int64
# College             364 non-null category
# Salary              364 non-null int64
# Sport               364 non-null category
# League              364 non-null category
# dtypes: category(6), float64(1), int64(4), object(1)
# memory usage: 30.5+ KB

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age  Age in Dog Years  \
# 0  Avery Bradley  Boston Celtics       0       PG   25             175.0
# 1    Jae Crowder  Boston Celtics      99       SF   25             175.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22             154.0
# 6  Jordan Mickey  Boston Celtics      55       PF   21             147.0
# 7   Kelly Olynyk  Boston Celtics      41        C   25             175.0
#
#   Height  Weight        College   Salary       Sport League
# 0    6-2     180          Texas  7730337  basketball    NBA
# 1    6-6     235      Marquette  6796117  basketball    NBA
# 3    6-5     185  Georgia State  1148640  basketball    NBA
# 6    6-8     235            LSU  1170960  basketball    NBA
# 7    7-0     238        Gonzaga  2165160  basketball    NBA

# %%
nba['Age in Dog Years'] = nba['Age in Dog Years'].astype("int")
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 12 columns):
# Name                364 non-null object
# Team                364 non-null category
# Number              364 non-null int64
# Position            364 non-null category
# Age                 364 non-null int64
# Age in Dog Years    364 non-null int64
# Height              364 non-null category
# Weight              364 non-null int64
# College             364 non-null category
# Salary              364 non-null int64
# Sport               364 non-null category
# League              364 non-null category
# dtypes: category(6), int64(5), object(1)
# memory usage: 30.5+ KB
